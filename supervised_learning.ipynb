# %% [markdown]
# # Supervised Learning
#
# * Simple Linear Reg
# * Multiple Linear Reg
# * Polynomial Reg
# * Logistic Reg
# * Decision Tree
# * Random Forest
# * x GBoost
#
# # Supervised Training Steps
#
# * Libraries importing
# * Dataset Load
# * Dataset Preprocessing
# * Labels $ Features division
# * Train $ Test Split
# * Model Training
# * Prediction
# * Accuracy
